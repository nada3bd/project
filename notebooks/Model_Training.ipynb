# %%
import pandas as pd

data = {
"text":[
"I have fever and headache",
"Severe chest pain and sweating",
"Mild cough and cold",
"High fever and vomiting",
"Difficulty breathing",
"Regular checkup feeling good",
"Sharp abdominal pain",
"Slight headache",
"Unconscious and not responding",
"Runny nose and sneezing"
],
"label":[
"sick",
"emergency",
"sick",
"sick",
"emergency",
"healthy",
"emergency",
"healthy",
"emergency",
"healthy"
]
}

df = pd.DataFrame(data)
df
# Out:
#                              text      label
# 0       I have fever and headache       sick
# 1  Severe chest pain and sweating  emergency
# 2             Mild cough and cold       sick
# 3         High fever and vomiting       sick
# 4            Difficulty breathing  emergency
# 5    Regular checkup feeling good    healthy
# 6            Sharp abdominal pain  emergency
# 7                 Slight headache    healthy
# 8  Unconscious and not responding  emergency
# 9         Runny nose and sneezing    healthy

# %%
import torch
import torch.nn as nn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df["text"]).toarray()

encoder = LabelEncoder()
y = encoder.fit_transform(df["label"])

X = torch.tensor(X).float()
y = torch.tensor(y)

# %%
model = nn.Sequential(
    nn.Linear(X.shape[1],16),
    nn.ReLU(),
    nn.Linear(16,3)
)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

for epoch in range(200):
    outputs = model(X)
    loss = loss_fn(outputs, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

print("Training finished ")
# Out:
# Training finished

# %%
torch.save(model.state_dict(), "medical_model.pt")
print("Model saved ")
# Out:
# Model saved

# %%
from google.colab import files
files.download("medical_model.pt")
